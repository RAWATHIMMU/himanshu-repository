# %%
import pandas as pd

# %%
pd.read_excel(r'C:\Users\Q300\Desktop\New Microsoft Excel Worksheet (2).xlsx')
# Out:
#      LINE SHIFT                 DATE         ODF      MODEL NAME  \
# 0       1     A           31/08/2022  IDX182766A          32ACER
# 1       1     A           31/08/2022  IDX182766A          34ACER
# 2       1     A           31/08/2022  IDX182766A          34ACER
# 3       1     A           31/08/2022  IDX182766A          34ACER
# 4       1     A           31/08/2022  IDX182766A          34ACER
# ..    ...   ...                  ...         ...             ...
# 190     1     A           17/10/2022  IDX183382J  AR40AR2841FDFL
# 191     1     A           17/10/2022  IDX183382J  AR40AR2841FDFL
# 192     1     A           17/10/2022  IDX183382J  AR40AR2841FDFL
# 193     1     A  2022-10-21 00:00:00  IDX182766E          65ACER
# 194     1     A  2022-10-21 00:00:00  IDX182766E          65ACER
#
#            PRID NUMBER     STAGE                             DEFECT  \
# 0    2208ATBH32SX00051  TESTING                         IR NOT WORK
# ...
